# %%
import os
import time
from shutil import move
import numpy as np
from subprocess import run
from subprocess import DEVNULL
from pathlib import Path as p
from multiprocessing import Pool
from shutil import move

# %%
work_dir = p('/media/Data/GoogleDriveNtust/dissertation_01/workFinal/workDir')
template = p('/media/Data/GoogleDriveNtust/dissertation_01/workFinal/templates/MNI152_T1_1mm_brain.nii')
template2mm = p('/media/Data/GoogleDriveNtust/dissertation_01/workFinal/templates/MNI152_T1_2mm_brain.nii')

# %%
derivatives = p(f'{work_dir}/test_dataset/derivatives')
binaries = os. getcwd()

os.chdir(derivatives)
os.chdir('../..')
results = os.getcwd()

outputResults = p(f'{results}/registration_results/processingTime')
try:
    os.mkdir(outputResults)
except OSError:
    pass

pipeline0 = p(f'{derivatives}/pipeline_0')
subject = os.listdir(pipeline0)
pipeline1 = p(f'{derivatives}/pipeline_1')
try:
    os.mkdir(pipeline1)
except OSError:
    pass

# %%
print('First Loop out of Six')
os.write(1, "FIRST Loop out of SIX".encode())

subjectNumber = ['Subject Number']
processingTime = ['Ants Processing Time (seconds)']

ants = p(f'{pipeline1}/ants')
try:
    os.mkdir(ants)
except OSError:
    pass

for i in range(len(subject)):
    
    antsSubject = p(f'{ants}/{subject[i]}')   
    try:
        os.mkdir(antsSubject)
    except OSError:
        pass
    
    movingImageName = os.listdir(f'{pipeline0}/{subject[i]}')
    movingImage = p(f'{pipeline0}/{subject[i]}/{movingImageName[0]}')

    os.chdir(antsSubject)
    
    start = time.time()
    
    rc = run(['antsRegistrationSyN.sh','-d', '3', '-f', f'{template}', '-m', f'{movingImage}', '-o', 'ants', '-n', '12'])
    
    end = time.time()
    processingTime.append(end - start)
    subjectNumber.append(subject[i])
          
    os.remove('ants0GenericAffine.mat')
    os.remove('ants1InverseWarp.nii.gz')
    os.remove('ants1Warp.nii.gz')
    os.remove('antsInverseWarped.nii.gz')
    
    print(end - start)    
    print('\n')
    print('@@@@@@@@@@@@@@')
fu = np.column_stack((subjectNumber, processingTime))

fubar = fu.transpose()

np.savetxt(p(f'{outputResults}/ANTS_time.csv'), fubar, fmt='%s', delimiter = ',')
# Out:
# First Loop out of Six
# 954.2971818447113
#
#
# @@@@@@@@@@@@@@
# 953.0997354984283
#
#
# @@@@@@@@@@@@@@
# 964.6382374763489
#
#
# @@@@@@@@@@@@@@
# 963.4995627403259
#
#
# @@@@@@@@@@@@@@
# 955.373918056488
#
#
# @@@@@@@@@@@@@@
# 962.645813703537
#
#
# @@@@@@@@@@@@@@
# 954.0991661548615
#
#
# @@@@@@@@@@@@@@
# 962.5893092155457
#
#
# @@@@@@@@@@@@@@
# 952.8087430000305
#
#
# @@@@@@@@@@@@@@
# 960.3488240242004
#
#
# @@@@@@@@@@@@@@
# 955.8234610557556
#
#
# @@@@@@@@@@@@@@
# 959.4661383628845
#
#
# @@@@@@@@@@@@@@
# 967.7269222736359
#
#
# @@@@@@@@@@@@@@
# 964.0279150009155
#
#
# @@@@@@@@@@@@@@
# 962.9542527198792
#
#
# @@@@@@@@@@@@@@
# 969.5148258209229
#
#
# @@@@@@@@@@@@@@
# 949.9180860519409
#
#
# @@@@@@@@@@@@@@
# 967.3272578716278
#
#
# @@@@@@@@@@@@@@
# 969.9709186553955
#
#
# @@@@@@@@@@@@@@
# 960.5481872558594
#
#
# @@@@@@@@@@@@@@
# 956.8367657661438
#
#
# @@@@@@@@@@@@@@
# 958.0041868686676
#
#
# @@@@@@@@@@@@@@
# 965.7859098911285
#
#
# @@@@@@@@@@@@@@
# 958.46510887146
#
#
# @@@@@@@@@@@@@@
# 964.4616236686707
#
#
# @@@@@@@@@@@@@@
# 963.7673523426056
#
#
# @@@@@@@@@@@@@@
# 964.770610332489
#
#
# @@@@@@@@@@@@@@
# 954.5568699836731
#
#
# @@@@@@@@@@@@@@
# 969.2775635719299
#
#
# @@@@@@@@@@@@@@
# 966.4999446868896
#
#
# @@@@@@@@@@@@@@
# 960.9554121494293
#
#
# @@@@@@@@@@@@@@
# 958.3372890949249
#
#
# @@@@@@@@@@@@@@
# 958.7656784057617
#
#
# @@@@@@@@@@@@@@
# 969.0210011005402
#
#
# @@@@@@@@@@@@@@
# 962.5352108478546
#
#
# @@@@@@@@@@@@@@
# 970.5571022033691
#
#
# @@@@@@@@@@@@@@
# 969.3253972530365
#
#
# @@@@@@@@@@@@@@
# 961.3255162239075
#
#
# @@@@@@@@@@@@@@
# 971.2315745353699
#
#
# @@@@@@@@@@@@@@
# 959.7820188999176
#
#
# @@@@@@@@@@@@@@
# 969.0375802516937
#
#
# @@@@@@@@@@@@@@
# 968.6847145557404
#
#
# @@@@@@@@@@@@@@
# 972.7467107772827
#
#
# @@@@@@@@@@@@@@
# 974.8525981903076
#
#
# @@@@@@@@@@@@@@
# 966.3707847595215
#
#
# @@@@@@@@@@@@@@
# 979.0968010425568
#
#
# @@@@@@@@@@@@@@
# 976.9577264785767
#
#
# @@@@@@@@@@@@@@
# 987.1598763465881
#
#
# @@@@@@@@@@@@@@
# 963.1401555538177
#
#
# @@@@@@@@@@@@@@
# 964.1215243339539
#
#
# @@@@@@@@@@@@@@

# %%
###ANTS QUICK LOOP

print('Second Loop out of Six')
os.write(1, "Second Loop out of SIX".encode())

subjectNumber = ['Subject Number']
processingTime = ['Ants Quick Processing Time (seconds)']

#ants Quick registration directory = ants
antsQuick = p(f'{pipeline1}/antsQuick')
try:
    os.mkdir(antsQuick)
except OSError:
    pass

#loop for full ants reg

for i in range(len(subject)):   
    antsQuickSubject = p(f'{antsQuick}/{subject[i]}')    
    try:
        os.mkdir(antsQuickSubject)
    except OSError:
        pass
       
    movingImageName = os.listdir(f'{pipeline0}/{subject[i]}')
    movingImage = p(f'{pipeline0}/{subject[i]}/{movingImageName[0]}')

    os.chdir(antsQuickSubject)
    
    start = time.time()
    
    run(f'antsRegistrationSyNQuick.sh -d 3 -f {template} -m {movingImage} -o antsQuick -n 12', shell=True)
    
    end = time.time()
    processingTime.append(end - start)
    subjectNumber.append(subject[i])
    
    os.remove('antsQuick0GenericAffine.mat')
    os.remove('antsQuick1InverseWarp.nii.gz')
    os.remove('antsQuick1Warp.nii.gz')
    os.remove('antsQuickInverseWarped.nii.gz')
    
    print(end - start)
    print('\n')
    print('@@@@@@@@@@@@@@')
fu = np.column_stack((subjectNumber, processingTime))
fubar = fu.transpose()

np.savetxt(p(f'{outputResults}/ANTSQuick_time.csv'), fubar, fmt='%s', delimiter = ',')
# Out:
# Second Loop out of Six
# 80.80019283294678
#
#
# @@@@@@@@@@@@@@
# 79.61937952041626
#
#
# @@@@@@@@@@@@@@
# 76.3774950504303
#
#
# @@@@@@@@@@@@@@
# 80.54161596298218
#
#
# @@@@@@@@@@@@@@
# 82.02373552322388
#
#
# @@@@@@@@@@@@@@
# 78.0926685333252
#
#
# @@@@@@@@@@@@@@
# 77.95963287353516
#
#
# @@@@@@@@@@@@@@
# 80.2907202243805
#
#
# @@@@@@@@@@@@@@
# 78.49532294273376
#
#
# @@@@@@@@@@@@@@
# 72.73694896697998
#
#
# @@@@@@@@@@@@@@
# 82.32879161834717
#
#
# @@@@@@@@@@@@@@
# 78.40255427360535
#
#
# @@@@@@@@@@@@@@
# 78.28429555892944
#
#
# @@@@@@@@@@@@@@
# 78.85009717941284
#
#
# @@@@@@@@@@@@@@
# 80.39240765571594
#
#
# @@@@@@@@@@@@@@
# 79.17874717712402
#
#
# @@@@@@@@@@@@@@
# 78.26964521408081
#
#
# @@@@@@@@@@@@@@
# 78.17767810821533
#
#
# @@@@@@@@@@@@@@
# 79.30146551132202
#
#
# @@@@@@@@@@@@@@
# 77.52239346504211
#
#
# @@@@@@@@@@@@@@
# 78.54198837280273
#
#
# @@@@@@@@@@@@@@
# 77.75481677055359
#
#
# @@@@@@@@@@@@@@
# 80.77667665481567
#
#
# @@@@@@@@@@@@@@
# 75.31953310966492
#
#
# @@@@@@@@@@@@@@
# 80.45242834091187
#
#
# @@@@@@@@@@@@@@
# 81.97439575195312
#
#
# @@@@@@@@@@@@@@
# 80.19057011604309
#
#
# @@@@@@@@@@@@@@
# 79.54118633270264
#
#
# @@@@@@@@@@@@@@
# 76.76372766494751
#
#
# @@@@@@@@@@@@@@
# 80.33783912658691
#
#
# @@@@@@@@@@@@@@
# 81.47388052940369
#
#
# @@@@@@@@@@@@@@
# 78.90346479415894
#
#
# @@@@@@@@@@@@@@
# 78.77274370193481
#
#
# @@@@@@@@@@@@@@
# 78.113205909729
#
#
# @@@@@@@@@@@@@@
# 73.78846597671509
#
#
# @@@@@@@@@@@@@@
# 78.7431800365448
#
#
# @@@@@@@@@@@@@@
# 81.16359233856201
#
#
# @@@@@@@@@@@@@@
# 79.06975483894348
#
#
# @@@@@@@@@@@@@@
# 79.14934062957764
#
#
# @@@@@@@@@@@@@@
# 77.88173294067383
#
#
# @@@@@@@@@@@@@@
# 82.422110080719
#
#
# @@@@@@@@@@@@@@
# 78.41010880470276
#
#
# @@@@@@@@@@@@@@
# 78.93412518501282
#
#
# @@@@@@@@@@@@@@
# 79.55464768409729
#
#
# @@@@@@@@@@@@@@
# 81.82605266571045
#
#
# @@@@@@@@@@@@@@
# 80.19299054145813
#
#
# @@@@@@@@@@@@@@
# 78.55172061920166
#
#
# @@@@@@@@@@@@@@
# 80.76662874221802
#
#
# @@@@@@@@@@@@@@
# 80.10437726974487
#
#
# @@@@@@@@@@@@@@
# 79.2796859741211
#
#
# @@@@@@@@@@@@@@

# %%
#ELASTIX LOOP

print('Third Loop out of Six')
os.write(1, "Third Loop out of SIX".encode())

subjectNumber = ['Subject Number']
processingTime = ['elastix Processing Time (seconds)']

p1 = 'Parameters_Translation.txt'
p2 = 'Parameters_Rigid.txt'
p3 = 'Parameters_Affine.txt'
p4 = 'Parameters_BSpline.txt'

#elastix registration directory = elastix
elastix = p(f'{pipeline1}/elastix')
try:
    os.mkdir(elastix)
except OSError:
    pass

#loop for full ants reg
for i in range(len(subject)):
    os.chdir(binaries)
    elastixSubject = p(f'{elastix}/{subject[i]}')

    try:
        os.mkdir(elastixSubject)
    except OSError:
        pass
    
    movingImageName = os.listdir(f'{pipeline0}/{subject[i]}')
    movingImage = p(f'{pipeline0}/{subject[i]}/{movingImageName[0]}')
    
    start = time.time()
    
    run(['elastix', '-f', f'{template}', '-m', f'{movingImage}', '-out', f'{elastixSubject}', '-p', f'{p1}','-p', f'{p2}','-p',f'{p3}','-p',f'{p4}', '-threads', '12'], stdout=DEVNULL)
    
    end = time.time()
    processingTime.append(end - start)
    subjectNumber.append(subject[i])
    
    os.chdir(elastixSubject)
    
    keepers = ['result.3.nii']

    for filename in os.listdir('.'):
        if filename not in keepers:
            print('Removing %s' % (filename,))
            os.remove(filename)
    
    print(end - start)
    print('\n')
    print('@@@@@@@@@@@@@@')
fu = np.column_stack((subjectNumber, processingTime))
fubar = fu.transpose()
np.savetxt(p(f'{outputResults}/Elastix_time.csv'), fubar, fmt='%s', delimiter = ',')
# Out:
# Fourth Loop out of Six
# Removing elastix.log
# Removing IterationInfo.0.R0.txt
# Removing IterationInfo.0.R1.txt
# Removing IterationInfo.0.R2.txt
# Removing IterationInfo.0.R3.txt
# Removing IterationInfo.1.R0.txt
# Removing IterationInfo.1.R1.txt
# Removing IterationInfo.1.R2.txt
# Removing IterationInfo.1.R3.txt
# Removing IterationInfo.2.R0.txt
# Removing IterationInfo.2.R1.txt
# Removing IterationInfo.2.R2.txt
# Removing IterationInfo.2.R3.txt
# Removing IterationInfo.3.R0.txt
# Removing IterationInfo.3.R1.txt
# Removing IterationInfo.3.R2.txt
# Removing IterationInfo.3.R3.txt
# Removing result.0.nii
# Removing result.1.nii
# Removing result.2.nii
# Removing TransformParameters.0.txt
# Removing TransformParameters.1.txt
# Removing TransformParameters.2.txt
# Removing TransformParameters.3.txt
# 37.15849828720093
#
#
# @@@@@@@@@@@@@@
# Removing elastix.log
# Removing IterationInfo.0.R0.txt
# Removing IterationInfo.0.R1.txt
# Removing IterationInfo.0.R2.txt
# Removing IterationInfo.0.R3.txt
# Removing IterationInfo.1.R0.txt
# Removing IterationInfo.1.R1.txt
# Removing IterationInfo.1.R2.txt
# Removing IterationInfo.1.R3.txt
# Removing IterationInfo.2.R0.txt
# Removing IterationInfo.2.R1.txt
# Removing IterationInfo.2.R2.txt
# Removing IterationInfo.2.R3.txt
# Removing IterationInfo.3.R0.txt
# Removing IterationInfo.3.R1.txt
# Removing IterationInfo.3.R2.txt
# Removing IterationInfo.3.R3.txt
# Removing result.0.nii
# Removing result.1.nii
# Removing result.2.nii
# Removing TransformParameters.0.txt
# Removing TransformParameters.1.txt
# Removing TransformParameters.2.txt
# Removing TransformParameters.3.txt
# 36.62311792373657
#
#
# @@@@@@@@@@@@@@
# Removing elastix.log
# Removing IterationInfo.0.R0.txt
# Removing IterationInfo.0.R1.txt
# Removing IterationInfo.0.R2.txt
# Removing IterationInfo.0.R3.txt
# Removing IterationInfo.1.R0.txt
# Removing IterationInfo.1.R1.txt
# Removing IterationInfo.1.R2.txt
# Removing IterationInfo.1.R3.txt
# Removing IterationInfo.2.R0.txt
# Removing IterationInfo.2.R1.txt
# Removing IterationInfo.2.R2.txt
# Removing IterationInfo.2.R3.txt
# Removing IterationInfo.3.R0.txt
# Removing IterationInfo.3.R1.txt
# Removing IterationInfo.3.R2.txt
# Removing IterationInfo.3.R3.txt
# Removing result.0.nii
# Removing result.1.nii
# Removing result.2.nii
# Removing TransformParameters.0.txt
# Removing TransformParameters.1.txt
# Removing TransformParameters.2.txt
# Removing TransformParameters.3.txt
# 35.8525824546814
#
#
# @@@@@@@@@@@@@@
# Removing elastix.log
# Removing IterationInfo.0.R0.txt
# Removing IterationInfo.0.R1.txt
# Removing IterationInfo.0.R2.txt
# Removing IterationInfo.0.R3.txt
# Removing IterationInfo.1.R0.txt
# Removing IterationInfo.1.R1.txt
# Removing IterationInfo.1.R2.txt
# Removing IterationInfo.1.R3.txt
# Removing IterationInfo.2.R0.txt
# Removing IterationInfo.2.R1.txt
# Removing IterationInfo.2.R2.txt
# Removing IterationInfo.2.R3.txt
# Removing IterationInfo.3.R0.txt
# Removing IterationInfo.3.R1.txt
# Removing IterationInfo.3.R2.txt
# Removing IterationInfo.3.R3.txt
# Removing result.0.nii
# Removing result.1.nii
# Removing result.2.nii
# Removing TransformParameters.0.txt
# Removing TransformParameters.1.txt
# Removing TransformParameters.2.txt
# Removing TransformParameters.3.txt
# 35.655813217163086
#
#
# @@@@@@@@@@@@@@
# Removing elastix.log
# Removing IterationInfo.0.R0.txt
# Removing IterationInfo.0.R1.txt
# Removing IterationInfo.0.R2.txt
# Removing IterationInfo.0.R3.txt
# Removing IterationInfo.1.R0.txt
# Removing IterationInfo.1.R1.txt
# Removing IterationInfo.1.R2.txt
# Removing IterationInfo.1.R3.txt
# Removing IterationInfo.2.R0.txt
# Removing IterationInfo.2.R1.txt
# Removing IterationInfo.2.R2.txt
# Removing IterationInfo.2.R3.txt
# Removing IterationInfo.3.R0.txt
# Removing IterationInfo.3.R1.txt
# Removing IterationInfo.3.R2.txt
# Removing IterationInfo.3.R3.txt
# Removing result.0.nii
# Removing result.1.nii
# Removing result.2.nii
# Removing TransformParameters.0.txt
# Removing TransformParameters.1.txt
# Removing TransformParameters.2.txt
# Removing TransformParameters.3.txt
# 36.28798699378967
#
#
# @@@@@@@@@@@@@@
# Removing elastix.log
# Removing IterationInfo.0.R0.txt
# Removing IterationInfo.0.R1.txt
# Removing IterationInfo.0.R2.txt
# Removing IterationInfo.0.R3.txt
# Removing IterationInfo.1.R0.txt
# Removing IterationInfo.1.R1.txt
# Removing IterationInfo.1.R2.txt
# Removing IterationInfo.1.R3.txt
# Removing IterationInfo.2.R0.txt
# Removing IterationInfo.2.R1.txt
# Removing IterationInfo.2.R2.txt
# Removing IterationInfo.2.R3.txt
# Removing IterationInfo.3.R0.txt
# Removing IterationInfo.3.R1.txt
# Removing IterationInfo.3.R2.txt
# Removing IterationInfo.3.R3.txt
# Removing result.0.nii
# Removing result.1.nii
# Removing result.2.nii
# Removing TransformParameters.0.txt
# Removing TransformParameters.1.txt
# Removing TransformParameters.2.txt
# Removing TransformParameters.3.txt
# 34.525970220565796
#
#
# @@@@@@@@@@@@@@
# Removing elastix.log
# Removing IterationInfo.0.R0.txt
# Removing IterationInfo.0.R1.txt
# Removing IterationInfo.0.R2.txt
# Removing IterationInfo.0.R3.txt
# Removing IterationInfo.1.R0.txt
# Removing IterationInfo.1.R1.txt
# Removing IterationInfo.1.R2.txt
# Removing IterationInfo.1.R3.txt
# Removing IterationInfo.2.R0.txt
# Removing IterationInfo.2.R1.txt
# Removing IterationInfo.2.R2.txt
# Removing IterationInfo.2.R3.txt
# Removing IterationInfo.3.R0.txt
# Removing IterationInfo.3.R1.txt
# Removing IterationInfo.3.R2.txt
# Removing IterationInfo.3.R3.txt
# Removing result.0.nii
# Removing result.1.nii
# Removing result.2.nii
# Removing TransformParameters.0.txt
# Removing TransformParameters.1.txt
# Removing TransformParameters.2.txt
# Removing TransformParameters.3.txt
# 36.034937620162964
#
#
# @@@@@@@@@@@@@@
# Removing elastix.log
# Removing IterationInfo.0.R0.txt
# Removing IterationInfo.0.R1.txt
# Removing IterationInfo.0.R2.txt
# Removing IterationInfo.0.R3.txt
# Removing IterationInfo.1.R0.txt
# Removing IterationInfo.1.R1.txt
# Removing IterationInfo.1.R2.txt
# Removing IterationInfo.1.R3.txt
# Removing IterationInfo.2.R0.txt
# Removing IterationInfo.2.R1.txt
# Removing IterationInfo.2.R2.txt
# Removing IterationInfo.2.R3.txt
# Removing IterationInfo.3.R0.txt
# Removing IterationInfo.3.R1.txt
# Removing IterationInfo.3.R2.txt
# Removing IterationInfo.3.R3.txt
# Removing result.0.nii
# Removing result.1.nii
# Removing result.2.nii
# Removing TransformParameters.0.txt
# Removing TransformParameters.1.txt
# Removing TransformParameters.2.txt
# Removing TransformParameters.3.txt
# 35.28610372543335
#
#
# @@@@@@@@@@@@@@
# Removing elastix.log
# Removing IterationInfo.0.R0.txt
# Removing IterationInfo.0.R1.txt
# Removing IterationInfo.0.R2.txt
# Removing IterationInfo.0.R3.txt
# Removing IterationInfo.1.R0.txt
# Removing IterationInfo.1.R1.txt
# Removing IterationInfo.1.R2.txt
# Removing IterationInfo.1.R3.txt
# Removing IterationInfo.2.R0.txt
# Removing IterationInfo.2.R1.txt
# Removing IterationInfo.2.R2.txt
# Removing IterationInfo.2.R3.txt
# Removing IterationInfo.3.R0.txt
# Removing IterationInfo.3.R1.txt
# Removing IterationInfo.3.R2.txt
# Removing IterationInfo.3.R3.txt
# Removing result.0.nii
# Removing result.1.nii
# Removing result.2.nii
# Removing TransformParameters.0.txt
# Removing TransformParameters.1.txt
# Removing TransformParameters.2.txt
# Removing TransformParameters.3.txt
# 36.120861530303955
#
#
# @@@@@@@@@@@@@@
# Removing elastix.log
# Removing IterationInfo.0.R0.txt
# Removing IterationInfo.0.R1.txt
# Removing IterationInfo.0.R2.txt
# Removing IterationInfo.0.R3.txt
# Removing IterationInfo.1.R0.txt
# Removing IterationInfo.1.R1.txt
# Removing IterationInfo.1.R2.txt
# Removing IterationInfo.1.R3.txt
# Removing IterationInfo.2.R0.txt
# Removing IterationInfo.2.R1.txt
# Removing IterationInfo.2.R2.txt
# Removing IterationInfo.2.R3.txt
# Removing IterationInfo.3.R0.txt
# Removing IterationInfo.3.R1.txt
# Removing IterationInfo.3.R2.txt
# Removing IterationInfo.3.R3.txt
# Removing result.0.nii
# Removing result.1.nii
# Removing result.2.nii
# Removing TransformParameters.0.txt
# Removing TransformParameters.1.txt
# Removing TransformParameters.2.txt
# Removing TransformParameters.3.txt
# 34.971131324768066
#
#
# @@@@@@@@@@@@@@
# Removing elastix.log
# Removing IterationInfo.0.R0.txt
# Removing IterationInfo.0.R1.txt
# Removing IterationInfo.0.R2.txt
# Removing IterationInfo.0.R3.txt
# Removing IterationInfo.1.R0.txt
# Removing IterationInfo.1.R1.txt
# Removing IterationInfo.1.R2.txt
# Removing IterationInfo.1.R3.txt
# Removing IterationInfo.2.R0.txt
# Removing IterationInfo.2.R1.txt
# Removing IterationInfo.2.R2.txt
# Removing IterationInfo.2.R3.txt
# Removing IterationInfo.3.R0.txt
# Removing IterationInfo.3.R1.txt
# Removing IterationInfo.3.R2.txt
# Removing IterationInfo.3.R3.txt
# Removing result.0.nii
# Removing result.1.nii
# Removing result.2.nii
# Removing TransformParameters.0.txt
# Removing TransformParameters.1.txt
# Removing TransformParameters.2.txt
# Removing TransformParameters.3.txt
# 34.77585983276367
#
#
# @@@@@@@@@@@@@@
# Removing elastix.log
# Removing IterationInfo.0.R0.txt
# Removing IterationInfo.0.R1.txt
# Removing IterationInfo.0.R2.txt
# Removing IterationInfo.0.R3.txt
# Removing IterationInfo.1.R0.txt
# Removing IterationInfo.1.R1.txt
# Removing IterationInfo.1.R2.txt
# Removing IterationInfo.1.R3.txt
# Removing IterationInfo.2.R0.txt
# Removing IterationInfo.2.R1.txt
# Removing IterationInfo.2.R2.txt
# Removing IterationInfo.2.R3.txt
# Removing IterationInfo.3.R0.txt
# Removing IterationInfo.3.R1.txt
# Removing IterationInfo.3.R2.txt
# Removing IterationInfo.3.R3.txt
# Removing result.0.nii
# Removing result.1.nii
# Removing result.2.nii
# Removing TransformParameters.0.txt
# Removing TransformParameters.1.txt
# Removing TransformParameters.2.txt
# Removing TransformParameters.3.txt
# 34.93250370025635
#
#
# @@@@@@@@@@@@@@
# Removing elastix.log
# Removing IterationInfo.0.R0.txt
# Removing IterationInfo.0.R1.txt
# Removing IterationInfo.0.R2.txt
# Removing IterationInfo.0.R3.txt
# Removing IterationInfo.1.R0.txt
# Removing IterationInfo.1.R1.txt
# Removing IterationInfo.1.R2.txt
# Removing IterationInfo.1.R3.txt
# Removing IterationInfo.2.R0.txt
# Removing IterationInfo.2.R1.txt
# Removing IterationInfo.2.R2.txt
# Removing IterationInfo.2.R3.txt
# Removing IterationInfo.3.R0.txt
# Removing IterationInfo.3.R1.txt
# Removing IterationInfo.3.R2.txt
# Removing IterationInfo.3.R3.txt
# Removing result.0.nii
# Removing result.1.nii
# Removing result.2.nii
# Removing TransformParameters.0.txt
# Removing TransformParameters.1.txt
# Removing TransformParameters.2.txt
# Removing TransformParameters.3.txt
# 35.49550986289978
#
#
# @@@@@@@@@@@@@@
# Removing elastix.log
# Removing IterationInfo.0.R0.txt
# Removing IterationInfo.0.R1.txt
# Removing IterationInfo.0.R2.txt
# Removing IterationInfo.0.R3.txt
# Removing IterationInfo.1.R0.txt
# Removing IterationInfo.1.R1.txt
# Removing IterationInfo.1.R2.txt
# Removing IterationInfo.1.R3.txt
# Removing IterationInfo.2.R0.txt
# Removing IterationInfo.2.R1.txt
# Removing IterationInfo.2.R2.txt
# Removing IterationInfo.2.R3.txt
# Removing IterationInfo.3.R0.txt
# Removing IterationInfo.3.R1.txt
# Removing IterationInfo.3.R2.txt
# Removing IterationInfo.3.R3.txt
# Removing result.0.nii
# Removing result.1.nii
# Removing result.2.nii
# Removing TransformParameters.0.txt
# Removing TransformParameters.1.txt
# Removing TransformParameters.2.txt
# Removing TransformParameters.3.txt
# 35.91008019447327
#
#
# @@@@@@@@@@@@@@
# Removing elastix.log
# Removing IterationInfo.0.R0.txt
# Removing IterationInfo.0.R1.txt
# Removing IterationInfo.0.R2.txt
# Removing IterationInfo.0.R3.txt
# Removing IterationInfo.1.R0.txt
# Removing IterationInfo.1.R1.txt
# Removing IterationInfo.1.R2.txt
# Removing IterationInfo.1.R3.txt
# Removing IterationInfo.2.R0.txt
# Removing IterationInfo.2.R1.txt
# Removing IterationInfo.2.R2.txt
# Removing IterationInfo.2.R3.txt
# Removing IterationInfo.3.R0.txt
# Removing IterationInfo.3.R1.txt
# Removing IterationInfo.3.R2.txt
# Removing IterationInfo.3.R3.txt
# Removing result.0.nii
# Removing result.1.nii
# Removing result.2.nii
# Removing TransformParameters.0.txt
# Removing TransformParameters.1.txt
# Removing TransformParameters.2.txt
# Removing TransformParameters.3.txt
# 37.61642003059387
#
#
# @@@@@@@@@@@@@@
# Removing elastix.log
# Removing IterationInfo.0.R0.txt
# Removing IterationInfo.0.R1.txt
# Removing IterationInfo.0.R2.txt
# Removing IterationInfo.0.R3.txt
# Removing IterationInfo.1.R0.txt
# Removing IterationInfo.1.R1.txt
# Removing IterationInfo.1.R2.txt
# Removing IterationInfo.1.R3.txt
# Removing IterationInfo.2.R0.txt
# Removing IterationInfo.2.R1.txt
# Removing IterationInfo.2.R2.txt
# Removing IterationInfo.2.R3.txt
# Removing IterationInfo.3.R0.txt
# Removing IterationInfo.3.R1.txt
# Removing IterationInfo.3.R2.txt
# Removing IterationInfo.3.R3.txt
# Removing result.0.nii
# Removing result.1.nii
# Removing result.2.nii
# Removing TransformParameters.0.txt
# Removing TransformParameters.1.txt
# Removing TransformParameters.2.txt
# Removing TransformParameters.3.txt
# 38.04247069358826
#
#
# @@@@@@@@@@@@@@
# Removing elastix.log
# Removing IterationInfo.0.R0.txt
# Removing IterationInfo.0.R1.txt
# Removing IterationInfo.0.R2.txt
# Removing IterationInfo.0.R3.txt
# Removing IterationInfo.1.R0.txt
# Removing IterationInfo.1.R1.txt
# Removing IterationInfo.1.R2.txt
# Removing IterationInfo.1.R3.txt
# Removing IterationInfo.2.R0.txt
# Removing IterationInfo.2.R1.txt
# Removing IterationInfo.2.R2.txt
# Removing IterationInfo.2.R3.txt
# Removing IterationInfo.3.R0.txt
# Removing IterationInfo.3.R1.txt
# Removing IterationInfo.3.R2.txt
# Removing IterationInfo.3.R3.txt
# Removing result.0.nii
# Removing result.1.nii
# Removing result.2.nii
# Removing TransformParameters.0.txt
# Removing TransformParameters.1.txt
# Removing TransformParameters.2.txt
# Removing TransformParameters.3.txt
# 38.654114723205566
#
#
# @@@@@@@@@@@@@@
# Removing elastix.log
# Removing IterationInfo.0.R0.txt
# Removing IterationInfo.0.R1.txt
# Removing IterationInfo.0.R2.txt
# Removing IterationInfo.0.R3.txt
# Removing IterationInfo.1.R0.txt
# Removing IterationInfo.1.R1.txt
# Removing IterationInfo.1.R2.txt
# Removing IterationInfo.1.R3.txt
# Removing IterationInfo.2.R0.txt
# Removing IterationInfo.2.R1.txt
# Removing IterationInfo.2.R2.txt
# Removing IterationInfo.2.R3.txt
# Removing IterationInfo.3.R0.txt
# Removing IterationInfo.3.R1.txt
# Removing IterationInfo.3.R2.txt
# Removing IterationInfo.3.R3.txt
# Removing result.0.nii
# Removing result.1.nii
# Removing result.2.nii
# Removing TransformParameters.0.txt
# Removing TransformParameters.1.txt
# Removing TransformParameters.2.txt
# Removing TransformParameters.3.txt
# 37.24300980567932
#
#
# @@@@@@@@@@@@@@
# Removing elastix.log
# Removing IterationInfo.0.R0.txt
# Removing IterationInfo.0.R1.txt
# Removing IterationInfo.0.R2.txt
# Removing IterationInfo.0.R3.txt
# Removing IterationInfo.1.R0.txt
# Removing IterationInfo.1.R1.txt
# Removing IterationInfo.1.R2.txt
# Removing IterationInfo.1.R3.txt
# Removing IterationInfo.2.R0.txt
# Removing IterationInfo.2.R1.txt
# Removing IterationInfo.2.R2.txt
# Removing IterationInfo.2.R3.txt
# Removing IterationInfo.3.R0.txt
# Removing IterationInfo.3.R1.txt
# Removing IterationInfo.3.R2.txt
# Removing IterationInfo.3.R3.txt
# Removing result.0.nii
# Removing result.1.nii
# Removing result.2.nii
# Removing TransformParameters.0.txt
# Removing TransformParameters.1.txt
# Removing TransformParameters.2.txt
# Removing TransformParameters.3.txt
# 35.89245343208313
#
#
# @@@@@@@@@@@@@@
# Removing elastix.log
# Removing IterationInfo.0.R0.txt
# Removing IterationInfo.0.R1.txt
# Removing IterationInfo.0.R2.txt
# Removing IterationInfo.0.R3.txt
# Removing IterationInfo.1.R0.txt
# Removing IterationInfo.1.R1.txt
# Removing IterationInfo.1.R2.txt
# Removing IterationInfo.1.R3.txt
# Removing IterationInfo.2.R0.txt
# Removing IterationInfo.2.R1.txt
# Removing IterationInfo.2.R2.txt
# Removing IterationInfo.2.R3.txt
# Removing IterationInfo.3.R0.txt
# Removing IterationInfo.3.R1.txt
# Removing IterationInfo.3.R2.txt
# Removing IterationInfo.3.R3.txt
# Removing result.0.nii
# Removing result.1.nii
# Removing result.2.nii
# Removing TransformParameters.0.txt
# Removing TransformParameters.1.txt
# Removing TransformParameters.2.txt
# Removing TransformParameters.3.txt
# 35.832454442977905
#
#
# @@@@@@@@@@@@@@
# Removing elastix.log
# Removing IterationInfo.0.R0.txt
# Removing IterationInfo.0.R1.txt
# Removing IterationInfo.0.R2.txt
# Removing IterationInfo.0.R3.txt
# Removing IterationInfo.1.R0.txt
# Removing IterationInfo.1.R1.txt
# Removing IterationInfo.1.R2.txt
# Removing IterationInfo.1.R3.txt
# Removing IterationInfo.2.R0.txt
# Removing IterationInfo.2.R1.txt
# Removing IterationInfo.2.R2.txt
# Removing IterationInfo.2.R3.txt
# Removing IterationInfo.3.R0.txt
# Removing IterationInfo.3.R1.txt
# Removing IterationInfo.3.R2.txt
# Removing IterationInfo.3.R3.txt
# Removing result.0.nii
# Removing result.1.nii
# Removing result.2.nii
# Removing TransformParameters.0.txt
# Removing TransformParameters.1.txt
# Removing TransformParameters.2.txt
# Removing TransformParameters.3.txt
# 34.685450077056885
#
#
# @@@@@@@@@@@@@@
# Removing elastix.log
# Removing IterationInfo.0.R0.txt
# Removing IterationInfo.0.R1.txt
# Removing IterationInfo.0.R2.txt
# Removing IterationInfo.0.R3.txt
# Removing IterationInfo.1.R0.txt
# Removing IterationInfo.1.R1.txt
# Removing IterationInfo.1.R2.txt
# Removing IterationInfo.1.R3.txt
# Removing IterationInfo.2.R0.txt
# Removing IterationInfo.2.R1.txt
# Removing IterationInfo.2.R2.txt
# Removing IterationInfo.2.R3.txt
# Removing IterationInfo.3.R0.txt
# Removing IterationInfo.3.R1.txt
# Removing IterationInfo.3.R2.txt
# Removing IterationInfo.3.R3.txt
# Removing result.0.nii
# Removing result.1.nii
# Removing result.2.nii
# Removing TransformParameters.0.txt
# Removing TransformParameters.1.txt
# Removing TransformParameters.2.txt
# Removing TransformParameters.3.txt
# 35.42007088661194
#
#
# @@@@@@@@@@@@@@
# Removing elastix.log
# Removing IterationInfo.0.R0.txt
# Removing IterationInfo.0.R1.txt
# Removing IterationInfo.0.R2.txt
# Removing IterationInfo.0.R3.txt
# Removing IterationInfo.1.R0.txt
# Removing IterationInfo.1.R1.txt
# Removing IterationInfo.1.R2.txt
# Removing IterationInfo.1.R3.txt
# Removing IterationInfo.2.R0.txt
# Removing IterationInfo.2.R1.txt
# Removing IterationInfo.2.R2.txt
# Removing IterationInfo.2.R3.txt
# Removing IterationInfo.3.R0.txt
# Removing IterationInfo.3.R1.txt
# Removing IterationInfo.3.R2.txt
# Removing IterationInfo.3.R3.txt
# Removing result.0.nii
# Removing result.1.nii
# Removing result.2.nii
# Removing TransformParameters.0.txt
# Removing TransformParameters.1.txt
# Removing TransformParameters.2.txt
# Removing TransformParameters.3.txt
# 35.005149602890015
#
#
# @@@@@@@@@@@@@@
# Removing elastix.log
# Removing IterationInfo.0.R0.txt
# Removing IterationInfo.0.R1.txt
# Removing IterationInfo.0.R2.txt
# Removing IterationInfo.0.R3.txt
# Removing IterationInfo.1.R0.txt
# Removing IterationInfo.1.R1.txt
# Removing IterationInfo.1.R2.txt
# Removing IterationInfo.1.R3.txt
# Removing IterationInfo.2.R0.txt
# Removing IterationInfo.2.R1.txt
# Removing IterationInfo.2.R2.txt
# Removing IterationInfo.2.R3.txt
# Removing IterationInfo.3.R0.txt
# Removing IterationInfo.3.R1.txt
# Removing IterationInfo.3.R2.txt
# Removing IterationInfo.3.R3.txt
# Removing result.0.nii
# Removing result.1.nii
# Removing result.2.nii
# Removing TransformParameters.0.txt
# Removing TransformParameters.1.txt
# Removing TransformParameters.2.txt
# Removing TransformParameters.3.txt
# 34.800151348114014
#
#
# @@@@@@@@@@@@@@
# Removing elastix.log
# Removing IterationInfo.0.R0.txt
# Removing IterationInfo.0.R1.txt
# Removing IterationInfo.0.R2.txt
# Removing IterationInfo.0.R3.txt
# Removing IterationInfo.1.R0.txt
# Removing IterationInfo.1.R1.txt
# Removing IterationInfo.1.R2.txt
# Removing IterationInfo.1.R3.txt
# Removing IterationInfo.2.R0.txt
# Removing IterationInfo.2.R1.txt
# Removing IterationInfo.2.R2.txt
# Removing IterationInfo.2.R3.txt
# Removing IterationInfo.3.R0.txt
# Removing IterationInfo.3.R1.txt
# Removing IterationInfo.3.R2.txt
# Removing IterationInfo.3.R3.txt
# Removing result.0.nii
# Removing result.1.nii
# Removing result.2.nii
# Removing TransformParameters.0.txt
# Removing TransformParameters.1.txt
# Removing TransformParameters.2.txt
# Removing TransformParameters.3.txt
# 35.49087452888489
#
#
# @@@@@@@@@@@@@@
# Removing elastix.log
# Removing IterationInfo.0.R0.txt
# Removing IterationInfo.0.R1.txt
# Removing IterationInfo.0.R2.txt
# Removing IterationInfo.0.R3.txt
# Removing IterationInfo.1.R0.txt
# Removing IterationInfo.1.R1.txt
# Removing IterationInfo.1.R2.txt
# Removing IterationInfo.1.R3.txt
# Removing IterationInfo.2.R0.txt
# Removing IterationInfo.2.R1.txt
# Removing IterationInfo.2.R2.txt
# Removing IterationInfo.2.R3.txt
# Removing IterationInfo.3.R0.txt
# Removing IterationInfo.3.R1.txt
# Removing IterationInfo.3.R2.txt
# Removing IterationInfo.3.R3.txt
# Removing result.0.nii
# Removing result.1.nii
# Removing result.2.nii
# Removing TransformParameters.0.txt
# Removing TransformParameters.1.txt
# Removing TransformParameters.2.txt
# Removing TransformParameters.3.txt
# 34.837388038635254
#
#
# @@@@@@@@@@@@@@
# Removing elastix.log
# Removing IterationInfo.0.R0.txt
# Removing IterationInfo.0.R1.txt
# Removing IterationInfo.0.R2.txt
# Removing IterationInfo.0.R3.txt
# Removing IterationInfo.1.R0.txt
# Removing IterationInfo.1.R1.txt
# Removing IterationInfo.1.R2.txt
# Removing IterationInfo.1.R3.txt
# Removing IterationInfo.2.R0.txt
# Removing IterationInfo.2.R1.txt
# Removing IterationInfo.2.R2.txt
# Removing IterationInfo.2.R3.txt
# Removing IterationInfo.3.R0.txt
# Removing IterationInfo.3.R1.txt
# Removing IterationInfo.3.R2.txt
# Removing IterationInfo.3.R3.txt
# Removing result.0.nii
# Removing result.1.nii
# Removing result.2.nii
# Removing TransformParameters.0.txt
# Removing TransformParameters.1.txt
# Removing TransformParameters.2.txt
# Removing TransformParameters.3.txt
# 36.06976652145386
#
#
# @@@@@@@@@@@@@@
# Removing elastix.log
# Removing IterationInfo.0.R0.txt
# Removing IterationInfo.0.R1.txt
# Removing IterationInfo.0.R2.txt
# Removing IterationInfo.0.R3.txt
# Removing IterationInfo.1.R0.txt
# Removing IterationInfo.1.R1.txt
# Removing IterationInfo.1.R2.txt
# Removing IterationInfo.1.R3.txt
# Removing IterationInfo.2.R0.txt
# Removing IterationInfo.2.R1.txt
# Removing IterationInfo.2.R2.txt
# Removing IterationInfo.2.R3.txt
# Removing IterationInfo.3.R0.txt
# Removing IterationInfo.3.R1.txt
# Removing IterationInfo.3.R2.txt
# Removing IterationInfo.3.R3.txt
# Removing result.0.nii
# Removing result.1.nii
# Removing result.2.nii
# Removing TransformParameters.0.txt
# Removing TransformParameters.1.txt
# Removing TransformParameters.2.txt
# Removing TransformParameters.3.txt
# 35.30847144126892
#
#
# @@@@@@@@@@@@@@
# Removing elastix.log
# Removing IterationInfo.0.R0.txt
# Removing IterationInfo.0.R1.txt
# Removing IterationInfo.0.R2.txt
# Removing IterationInfo.0.R3.txt
# Removing IterationInfo.1.R0.txt
# Removing IterationInfo.1.R1.txt
# Removing IterationInfo.1.R2.txt
# Removing IterationInfo.1.R3.txt
# Removing IterationInfo.2.R0.txt
# Removing IterationInfo.2.R1.txt
# Removing IterationInfo.2.R2.txt
# Removing IterationInfo.2.R3.txt
# Removing IterationInfo.3.R0.txt
# Removing IterationInfo.3.R1.txt
# Removing IterationInfo.3.R2.txt
# Removing IterationInfo.3.R3.txt
# Removing result.0.nii
# Removing result.1.nii
# Removing result.2.nii
# Removing TransformParameters.0.txt
# Removing TransformParameters.1.txt
# Removing TransformParameters.2.txt
# Removing TransformParameters.3.txt
# 34.75312328338623
#
#
# @@@@@@@@@@@@@@
# Removing elastix.log
# Removing IterationInfo.0.R0.txt
# Removing IterationInfo.0.R1.txt
# Removing IterationInfo.0.R2.txt
# Removing IterationInfo.0.R3.txt
# Removing IterationInfo.1.R0.txt
# Removing IterationInfo.1.R1.txt
# Removing IterationInfo.1.R2.txt
# Removing IterationInfo.1.R3.txt
# Removing IterationInfo.2.R0.txt
# Removing IterationInfo.2.R1.txt
# Removing IterationInfo.2.R2.txt
# Removing IterationInfo.2.R3.txt
# Removing IterationInfo.3.R0.txt
# Removing IterationInfo.3.R1.txt
# Removing IterationInfo.3.R2.txt
# Removing IterationInfo.3.R3.txt
# Removing result.0.nii
# Removing result.1.nii
# Removing result.2.nii
# Removing TransformParameters.0.txt
# Removing TransformParameters.1.txt
# Removing TransformParameters.2.txt
# Removing TransformParameters.3.txt
# 35.90012764930725
#
#
# @@@@@@@@@@@@@@
# Removing elastix.log
# Removing IterationInfo.0.R0.txt
# Removing IterationInfo.0.R1.txt
# Removing IterationInfo.0.R2.txt
# Removing IterationInfo.0.R3.txt
# Removing IterationInfo.1.R0.txt
# Removing IterationInfo.1.R1.txt
# Removing IterationInfo.1.R2.txt
# Removing IterationInfo.1.R3.txt
# Removing IterationInfo.2.R0.txt
# Removing IterationInfo.2.R1.txt
# Removing IterationInfo.2.R2.txt
# Removing IterationInfo.2.R3.txt
# Removing IterationInfo.3.R0.txt
# Removing IterationInfo.3.R1.txt
# Removing IterationInfo.3.R2.txt
# Removing IterationInfo.3.R3.txt
# Removing result.0.nii
# Removing result.1.nii
# Removing result.2.nii
# Removing TransformParameters.0.txt
# Removing TransformParameters.1.txt
# Removing TransformParameters.2.txt
# Removing TransformParameters.3.txt
# 35.48834943771362
#
#
# @@@@@@@@@@@@@@
# Removing elastix.log
# Removing IterationInfo.0.R0.txt
# Removing IterationInfo.0.R1.txt
# Removing IterationInfo.0.R2.txt
# Removing IterationInfo.0.R3.txt
# Removing IterationInfo.1.R0.txt
# Removing IterationInfo.1.R1.txt
# Removing IterationInfo.1.R2.txt
# Removing IterationInfo.1.R3.txt
# Removing IterationInfo.2.R0.txt
# Removing IterationInfo.2.R1.txt
# Removing IterationInfo.2.R2.txt
# Removing IterationInfo.2.R3.txt
# Removing IterationInfo.3.R0.txt
# Removing IterationInfo.3.R1.txt
# Removing IterationInfo.3.R2.txt
# Removing IterationInfo.3.R3.txt
# Removing result.0.nii
# Removing result.1.nii
# Removing result.2.nii
# Removing TransformParameters.0.txt
# Removing TransformParameters.1.txt
# Removing TransformParameters.2.txt
# Removing TransformParameters.3.txt
# 36.06891632080078
#
#
# @@@@@@@@@@@@@@
# Removing elastix.log
# Removing IterationInfo.0.R0.txt
# Removing IterationInfo.0.R1.txt
# Removing IterationInfo.0.R2.txt
# Removing IterationInfo.0.R3.txt
# Removing IterationInfo.1.R0.txt
# Removing IterationInfo.1.R1.txt
# Removing IterationInfo.1.R2.txt
# Removing IterationInfo.1.R3.txt
# Removing IterationInfo.2.R0.txt
# Removing IterationInfo.2.R1.txt
# Removing IterationInfo.2.R2.txt
# Removing IterationInfo.2.R3.txt
# Removing IterationInfo.3.R0.txt
# Removing IterationInfo.3.R1.txt
# Removing IterationInfo.3.R2.txt
# Removing IterationInfo.3.R3.txt
# Removing result.0.nii
# Removing result.1.nii
# Removing result.2.nii
# Removing TransformParameters.0.txt
# Removing TransformParameters.1.txt
# Removing TransformParameters.2.txt
# Removing TransformParameters.3.txt
# 35.01446843147278
#
#
# @@@@@@@@@@@@@@
# Removing elastix.log
# Removing IterationInfo.0.R0.txt
# Removing IterationInfo.0.R1.txt
# Removing IterationInfo.0.R2.txt
# Removing IterationInfo.0.R3.txt
# Removing IterationInfo.1.R0.txt
# Removing IterationInfo.1.R1.txt
# Removing IterationInfo.1.R2.txt
# Removing IterationInfo.1.R3.txt
# Removing IterationInfo.2.R0.txt
# Removing IterationInfo.2.R1.txt
# Removing IterationInfo.2.R2.txt
# Removing IterationInfo.2.R3.txt
# Removing IterationInfo.3.R0.txt
# Removing IterationInfo.3.R1.txt
# Removing IterationInfo.3.R2.txt
# Removing IterationInfo.3.R3.txt
# Removing result.0.nii
# Removing result.1.nii
# Removing result.2.nii
# Removing TransformParameters.0.txt
# Removing TransformParameters.1.txt
# Removing TransformParameters.2.txt
# Removing TransformParameters.3.txt
# 35.072829723358154
#
#
# @@@@@@@@@@@@@@
# Removing elastix.log
# Removing IterationInfo.0.R0.txt
# Removing IterationInfo.0.R1.txt
# Removing IterationInfo.0.R2.txt
# Removing IterationInfo.0.R3.txt
# Removing IterationInfo.1.R0.txt
# Removing IterationInfo.1.R1.txt
# Removing IterationInfo.1.R2.txt
# Removing IterationInfo.1.R3.txt
# Removing IterationInfo.2.R0.txt
# Removing IterationInfo.2.R1.txt
# Removing IterationInfo.2.R2.txt
# Removing IterationInfo.2.R3.txt
# Removing IterationInfo.3.R0.txt
# Removing IterationInfo.3.R1.txt
# Removing IterationInfo.3.R2.txt
# Removing IterationInfo.3.R3.txt
# Removing result.0.nii
# Removing result.1.nii
# Removing result.2.nii
# Removing TransformParameters.0.txt
# Removing TransformParameters.1.txt
# Removing TransformParameters.2.txt
# Removing TransformParameters.3.txt
# 35.30708050727844
#
#
# @@@@@@@@@@@@@@
# Removing elastix.log
# Removing IterationInfo.0.R0.txt
# Removing IterationInfo.0.R1.txt
# Removing IterationInfo.0.R2.txt
# Removing IterationInfo.0.R3.txt
# Removing IterationInfo.1.R0.txt
# Removing IterationInfo.1.R1.txt
# Removing IterationInfo.1.R2.txt
# Removing IterationInfo.1.R3.txt
# Removing IterationInfo.2.R0.txt
# Removing IterationInfo.2.R1.txt
# Removing IterationInfo.2.R2.txt
# Removing IterationInfo.2.R3.txt
# Removing IterationInfo.3.R0.txt
# Removing IterationInfo.3.R1.txt
# Removing IterationInfo.3.R2.txt
# Removing IterationInfo.3.R3.txt
# Removing result.0.nii
# Removing result.1.nii
# Removing result.2.nii
# Removing TransformParameters.0.txt
# Removing TransformParameters.1.txt
# Removing TransformParameters.2.txt
# Removing TransformParameters.3.txt
# 36.47453784942627
#
#
# @@@@@@@@@@@@@@
# Removing elastix.log
# Removing IterationInfo.0.R0.txt
# Removing IterationInfo.0.R1.txt
# Removing IterationInfo.0.R2.txt
# Removing IterationInfo.0.R3.txt
# Removing IterationInfo.1.R0.txt
# Removing IterationInfo.1.R1.txt
# Removing IterationInfo.1.R2.txt
# Removing IterationInfo.1.R3.txt
# Removing IterationInfo.2.R0.txt
# Removing IterationInfo.2.R1.txt
# Removing IterationInfo.2.R2.txt
# Removing IterationInfo.2.R3.txt
# Removing IterationInfo.3.R0.txt
# Removing IterationInfo.3.R1.txt
# Removing IterationInfo.3.R2.txt
# Removing IterationInfo.3.R3.txt
# Removing result.0.nii
# Removing result.1.nii
# Removing result.2.nii
# Removing TransformParameters.0.txt
# Removing TransformParameters.1.txt
# Removing TransformParameters.2.txt
# Removing TransformParameters.3.txt
# 35.51440477371216
#
#
# @@@@@@@@@@@@@@
# Removing elastix.log
# Removing IterationInfo.0.R0.txt
# Removing IterationInfo.0.R1.txt
# Removing IterationInfo.0.R2.txt
# Removing IterationInfo.0.R3.txt
# Removing IterationInfo.1.R0.txt
# Removing IterationInfo.1.R1.txt
# Removing IterationInfo.1.R2.txt
# Removing IterationInfo.1.R3.txt
# Removing IterationInfo.2.R0.txt
# Removing IterationInfo.2.R1.txt
# Removing IterationInfo.2.R2.txt
# Removing IterationInfo.2.R3.txt
# Removing IterationInfo.3.R0.txt
# Removing IterationInfo.3.R1.txt
# Removing IterationInfo.3.R2.txt
# Removing IterationInfo.3.R3.txt
# Removing result.0.nii
# Removing result.1.nii
# Removing result.2.nii
# Removing TransformParameters.0.txt
# Removing TransformParameters.1.txt
# Removing TransformParameters.2.txt
# Removing TransformParameters.3.txt
# 35.216508865356445
#
#
# @@@@@@@@@@@@@@
# Removing elastix.log
# Removing IterationInfo.0.R0.txt
# Removing IterationInfo.0.R1.txt
# Removing IterationInfo.0.R2.txt
# Removing IterationInfo.0.R3.txt
# Removing IterationInfo.1.R0.txt
# Removing IterationInfo.1.R1.txt
# Removing IterationInfo.1.R2.txt
# Removing IterationInfo.1.R3.txt
# Removing IterationInfo.2.R0.txt
# Removing IterationInfo.2.R1.txt
# Removing IterationInfo.2.R2.txt
# Removing IterationInfo.2.R3.txt
# Removing IterationInfo.3.R0.txt
# Removing IterationInfo.3.R1.txt
# Removing IterationInfo.3.R2.txt
# Removing IterationInfo.3.R3.txt
# Removing result.0.nii
# Removing result.1.nii
# Removing result.2.nii
# Removing TransformParameters.0.txt
# Removing TransformParameters.1.txt
# Removing TransformParameters.2.txt
# Removing TransformParameters.3.txt
# 36.259767293930054
#
#
# @@@@@@@@@@@@@@
# Removing elastix.log
# Removing IterationInfo.0.R0.txt
# Removing IterationInfo.0.R1.txt
# Removing IterationInfo.0.R2.txt
# Removing IterationInfo.0.R3.txt
# Removing IterationInfo.1.R0.txt
# Removing IterationInfo.1.R1.txt
# Removing IterationInfo.1.R2.txt
# Removing IterationInfo.1.R3.txt
# Removing IterationInfo.2.R0.txt
# Removing IterationInfo.2.R1.txt
# Removing IterationInfo.2.R2.txt
# Removing IterationInfo.2.R3.txt
# Removing IterationInfo.3.R0.txt
# Removing IterationInfo.3.R1.txt
# Removing IterationInfo.3.R2.txt
# Removing IterationInfo.3.R3.txt
# Removing result.0.nii
# Removing result.1.nii
# Removing result.2.nii
# Removing TransformParameters.0.txt
# Removing TransformParameters.1.txt
# Removing TransformParameters.2.txt
# Removing TransformParameters.3.txt
# 35.1124529838562
#
#
# @@@@@@@@@@@@@@
# Removing elastix.log
# Removing IterationInfo.0.R0.txt
# Removing IterationInfo.0.R1.txt
# Removing IterationInfo.0.R2.txt
# Removing IterationInfo.0.R3.txt
# Removing IterationInfo.1.R0.txt
# Removing IterationInfo.1.R1.txt
# Removing IterationInfo.1.R2.txt
# Removing IterationInfo.1.R3.txt
# Removing IterationInfo.2.R0.txt
# Removing IterationInfo.2.R1.txt
# Removing IterationInfo.2.R2.txt
# Removing IterationInfo.2.R3.txt
# Removing IterationInfo.3.R0.txt
# Removing IterationInfo.3.R1.txt
# Removing IterationInfo.3.R2.txt
# Removing IterationInfo.3.R3.txt
# Removing result.0.nii
# Removing result.1.nii
# Removing result.2.nii
# Removing TransformParameters.0.txt
# Removing TransformParameters.1.txt
# Removing TransformParameters.2.txt
# Removing TransformParameters.3.txt
# 35.09524893760681
#
#
# @@@@@@@@@@@@@@
# Removing elastix.log
# Removing IterationInfo.0.R0.txt
# Removing IterationInfo.0.R1.txt
# Removing IterationInfo.0.R2.txt
# Removing IterationInfo.0.R3.txt
# Removing IterationInfo.1.R0.txt
# Removing IterationInfo.1.R1.txt
# Removing IterationInfo.1.R2.txt
# Removing IterationInfo.1.R3.txt
# Removing IterationInfo.2.R0.txt
# Removing IterationInfo.2.R1.txt
# Removing IterationInfo.2.R2.txt
# Removing IterationInfo.2.R3.txt
# Removing IterationInfo.3.R0.txt
# Removing IterationInfo.3.R1.txt
# Removing IterationInfo.3.R2.txt
# Removing IterationInfo.3.R3.txt
# Removing result.0.nii
# Removing result.1.nii
# Removing result.2.nii
# Removing TransformParameters.0.txt
# Removing TransformParameters.1.txt
# Removing TransformParameters.2.txt
# Removing TransformParameters.3.txt
# 35.496718406677246
#
#
# @@@@@@@@@@@@@@
# Removing elastix.log
# Removing IterationInfo.0.R0.txt
# Removing IterationInfo.0.R1.txt
# Removing IterationInfo.0.R2.txt
# Removing IterationInfo.0.R3.txt
# Removing IterationInfo.1.R0.txt
# Removing IterationInfo.1.R1.txt
# Removing IterationInfo.1.R2.txt
# Removing IterationInfo.1.R3.txt
# Removing IterationInfo.2.R0.txt
# Removing IterationInfo.2.R1.txt
# Removing IterationInfo.2.R2.txt
# Removing IterationInfo.2.R3.txt
# Removing IterationInfo.3.R0.txt
# Removing IterationInfo.3.R1.txt
# Removing IterationInfo.3.R2.txt
# Removing IterationInfo.3.R3.txt
# Removing result.0.nii
# Removing result.1.nii
# Removing result.2.nii
# Removing TransformParameters.0.txt
# Removing TransformParameters.1.txt
# Removing TransformParameters.2.txt
# Removing TransformParameters.3.txt
# 36.3837628364563
#
#
# @@@@@@@@@@@@@@
# Removing elastix.log
# Removing IterationInfo.0.R0.txt
# Removing IterationInfo.0.R1.txt
# Removing IterationInfo.0.R2.txt
# Removing IterationInfo.0.R3.txt
# Removing IterationInfo.1.R0.txt
# Removing IterationInfo.1.R1.txt
# Removing IterationInfo.1.R2.txt
# Removing IterationInfo.1.R3.txt
# Removing IterationInfo.2.R0.txt
# Removing IterationInfo.2.R1.txt
# Removing IterationInfo.2.R2.txt
# Removing IterationInfo.2.R3.txt
# Removing IterationInfo.3.R0.txt
# Removing IterationInfo.3.R1.txt
# Removing IterationInfo.3.R2.txt
# Removing IterationInfo.3.R3.txt
# Removing result.0.nii
# Removing result.1.nii
# Removing result.2.nii
# Removing TransformParameters.0.txt
# Removing TransformParameters.1.txt
# Removing TransformParameters.2.txt
# Removing TransformParameters.3.txt
# 36.97926306724548
#
#
# @@@@@@@@@@@@@@
# Removing elastix.log
# Removing IterationInfo.0.R0.txt
# Removing IterationInfo.0.R1.txt
# Removing IterationInfo.0.R2.txt
# Removing IterationInfo.0.R3.txt
# Removing IterationInfo.1.R0.txt
# Removing IterationInfo.1.R1.txt
# Removing IterationInfo.1.R2.txt
# Removing IterationInfo.1.R3.txt
# Removing IterationInfo.2.R0.txt
# Removing IterationInfo.2.R1.txt
# Removing IterationInfo.2.R2.txt
# Removing IterationInfo.2.R3.txt
# Removing IterationInfo.3.R0.txt
# Removing IterationInfo.3.R1.txt
# Removing IterationInfo.3.R2.txt
# Removing IterationInfo.3.R3.txt
# Removing result.0.nii
# Removing result.1.nii
# Removing result.2.nii
# Removing TransformParameters.0.txt
# Removing TransformParameters.1.txt
# Removing TransformParameters.2.txt
# Removing TransformParameters.3.txt
# 35.25137209892273
#
#
# @@@@@@@@@@@@@@
# Removing elastix.log
# Removing IterationInfo.0.R0.txt
# Removing IterationInfo.0.R1.txt
# Removing IterationInfo.0.R2.txt
# Removing IterationInfo.0.R3.txt
# Removing IterationInfo.1.R0.txt
# Removing IterationInfo.1.R1.txt
# Removing IterationInfo.1.R2.txt
# Removing IterationInfo.1.R3.txt
# Removing IterationInfo.2.R0.txt
# Removing IterationInfo.2.R1.txt
# Removing IterationInfo.2.R2.txt
# Removing IterationInfo.2.R3.txt
# Removing IterationInfo.3.R0.txt
# Removing IterationInfo.3.R1.txt
# Removing IterationInfo.3.R2.txt
# Removing IterationInfo.3.R3.txt
# Removing result.0.nii
# Removing result.1.nii
# Removing result.2.nii
# Removing TransformParameters.0.txt
# Removing TransformParameters.1.txt
# Removing TransformParameters.2.txt
# Removing TransformParameters.3.txt
# 36.213623046875
#
#
# @@@@@@@@@@@@@@
# Removing elastix.log
# Removing IterationInfo.0.R0.txt
# Removing IterationInfo.0.R1.txt
# Removing IterationInfo.0.R2.txt
# Removing IterationInfo.0.R3.txt
# Removing IterationInfo.1.R0.txt
# Removing IterationInfo.1.R1.txt
# Removing IterationInfo.1.R2.txt
# Removing IterationInfo.1.R3.txt
# Removing IterationInfo.2.R0.txt
# Removing IterationInfo.2.R1.txt
# Removing IterationInfo.2.R2.txt
# Removing IterationInfo.2.R3.txt
# Removing IterationInfo.3.R0.txt
# Removing IterationInfo.3.R1.txt
# Removing IterationInfo.3.R2.txt
# Removing IterationInfo.3.R3.txt
# Removing result.0.nii
# Removing result.1.nii
# Removing result.2.nii
# Removing TransformParameters.0.txt
# Removing TransformParameters.1.txt
# Removing TransformParameters.2.txt
# Removing TransformParameters.3.txt
# 35.36941576004028
#
#
# @@@@@@@@@@@@@@
# Removing elastix.log
# Removing IterationInfo.0.R0.txt
# Removing IterationInfo.0.R1.txt
# Removing IterationInfo.0.R2.txt
# Removing IterationInfo.0.R3.txt
# Removing IterationInfo.1.R0.txt
# Removing IterationInfo.1.R1.txt
# Removing IterationInfo.1.R2.txt
# Removing IterationInfo.1.R3.txt
# Removing IterationInfo.2.R0.txt
# Removing IterationInfo.2.R1.txt
# Removing IterationInfo.2.R2.txt
# Removing IterationInfo.2.R3.txt
# Removing IterationInfo.3.R0.txt
# Removing IterationInfo.3.R1.txt
# Removing IterationInfo.3.R2.txt
# Removing IterationInfo.3.R3.txt
# Removing result.0.nii
# Removing result.1.nii
# Removing result.2.nii
# Removing TransformParameters.0.txt
# Removing TransformParameters.1.txt
# Removing TransformParameters.2.txt
# Removing TransformParameters.3.txt
# 38.1604700088501
#
#
# @@@@@@@@@@@@@@
# Removing elastix.log
# Removing IterationInfo.0.R0.txt
# Removing IterationInfo.0.R1.txt
# Removing IterationInfo.0.R2.txt
# Removing IterationInfo.0.R3.txt
# Removing IterationInfo.1.R0.txt
# Removing IterationInfo.1.R1.txt
# Removing IterationInfo.1.R2.txt
# Removing IterationInfo.1.R3.txt
# Removing IterationInfo.2.R0.txt
# Removing IterationInfo.2.R1.txt
# Removing IterationInfo.2.R2.txt
# Removing IterationInfo.2.R3.txt
# Removing IterationInfo.3.R0.txt
# Removing IterationInfo.3.R1.txt
# Removing IterationInfo.3.R2.txt
# Removing IterationInfo.3.R3.txt
# Removing result.0.nii
# Removing result.1.nii
# Removing result.2.nii
# Removing TransformParameters.0.txt
# Removing TransformParameters.1.txt
# Removing TransformParameters.2.txt
# Removing TransformParameters.3.txt
# 36.719364643096924
#
#
# @@@@@@@@@@@@@@
# Removing elastix.log
# Removing IterationInfo.0.R0.txt
# Removing IterationInfo.0.R1.txt
# Removing IterationInfo.0.R2.txt
# Removing IterationInfo.0.R3.txt
# Removing IterationInfo.1.R0.txt
# Removing IterationInfo.1.R1.txt
# Removing IterationInfo.1.R2.txt
# Removing IterationInfo.1.R3.txt
# Removing IterationInfo.2.R0.txt
# Removing IterationInfo.2.R1.txt
# Removing IterationInfo.2.R2.txt
# Removing IterationInfo.2.R3.txt
# Removing IterationInfo.3.R0.txt
# Removing IterationInfo.3.R1.txt
# Removing IterationInfo.3.R2.txt
# Removing IterationInfo.3.R3.txt
# Removing result.0.nii
# Removing result.1.nii
# Removing result.2.nii
# Removing TransformParameters.0.txt
# Removing TransformParameters.1.txt
# Removing TransformParameters.2.txt
# Removing TransformParameters.3.txt
# 36.66160011291504
#
#
# @@@@@@@@@@@@@@

# %%
print('Fourth Loop out of Six')
os.write(1, "Fourth Loop out of SIX".encode())

subjectNumber = ['Subject Number']
processingTime = ['SPMpy Processing Time (seconds)']

spmPy = p(f'{pipeline1}/spmPy')
try:
    os.mkdir(spmPy)
except OSError:
    pass

for i in range(len(subject)):
    
    spmPySubject = p(f'{spmPy}/{subject[i]}')   
    try:
        os.mkdir(spmPySubject)
    except OSError:
        pass
    
    movingImageName = os.listdir(f'{pipeline0}/{subject[i]}')
    movingImage = p(f'{pipeline0}/{subject[i]}/{movingImageName[0]}')

    os.chdir(binaries)

    start = time.time()
    
    run(f'matlab -nodesktop -nosplash -r "try spmPy(\'{movingImage}\', \'{template}\'); catch; end; quit"', shell=True)
    
    end = time.time()
    processingTime.append(end - start)
    subjectNumber.append(subject[i])

    os.chdir(spmPySubject)
    
    outputFile = p(f'{pipeline0}/{subject[i]}/spmPywmbet_{subject[i]}.nii')
    run(f'fslmaths {outputFile} -nan spmPy_{subject[i]}', shell=True)
    
    os.chdir(p(f'{pipeline0}/{subject[i]}'))
    keepers = [f'bet_{subject[i]}.nii', f'bet_{subject[i]}_to_MNI152_T1_1mm_brain.log']
    for filename in os.listdir('.'):
        if filename not in keepers:
            os.remove(filename)
    
    print(end - start)    
    print('\n')
    print('@@@@@@@@@@@@@@')
fu = np.column_stack((subjectNumber, processingTime))

fubar = fu.transpose()

np.savetxt(p(f'{outputResults}/SPMpy_time.csv'), fubar, fmt='%s', delimiter = ',')
# Out:
# Fifth Loop out of Six
# 176.36544704437256
#
#
# @@@@@@@@@@@@@@
# 130.16881823539734
#
#
# @@@@@@@@@@@@@@
# 129.01805114746094
#
#
# @@@@@@@@@@@@@@
# 126.70817589759827
#
#
# @@@@@@@@@@@@@@
# 124.98284387588501
#
#
# @@@@@@@@@@@@@@
# 133.7065258026123
#
#
# @@@@@@@@@@@@@@
# 128.96974301338196
#
#
# @@@@@@@@@@@@@@
# 132.94892191886902
#
#
# @@@@@@@@@@@@@@
# 134.25844931602478
#
#
# @@@@@@@@@@@@@@
# 127.2440550327301
#
#
# @@@@@@@@@@@@@@
# 130.57486248016357
#
#
# @@@@@@@@@@@@@@
# 135.80116319656372
#
#
# @@@@@@@@@@@@@@
# 133.92759132385254
#
#
# @@@@@@@@@@@@@@
# 125.87442207336426
#
#
# @@@@@@@@@@@@@@
# 131.05325436592102
#
#
# @@@@@@@@@@@@@@
# 128.4806580543518
#
#
# @@@@@@@@@@@@@@
# 120.24647545814514
#
#
# @@@@@@@@@@@@@@
# 122.45513892173767
#
#
# @@@@@@@@@@@@@@
# 121.5352852344513
#
#
# @@@@@@@@@@@@@@
# 167.95051503181458
#
#
# @@@@@@@@@@@@@@
# 123.53000020980835
#
#
# @@@@@@@@@@@@@@
# 123.32211184501648
#
#
# @@@@@@@@@@@@@@
# 120.695561170578
#
#
# @@@@@@@@@@@@@@
# 119.79590201377869
#
#
# @@@@@@@@@@@@@@
# 118.85108876228333
#
#
# @@@@@@@@@@@@@@
# 123.2148802280426
#
#
# @@@@@@@@@@@@@@
# 123.95907020568848
#
#
# @@@@@@@@@@@@@@
# 119.65257239341736
#
#
# @@@@@@@@@@@@@@
# 124.94704055786133
#
#
# @@@@@@@@@@@@@@
# 122.84115505218506
#
#
# @@@@@@@@@@@@@@
# 120.25077080726624
#
#
# @@@@@@@@@@@@@@
# 132.5499517917633
#
#
# @@@@@@@@@@@@@@
# 129.8810966014862
#
#
# @@@@@@@@@@@@@@
# 131.25839138031006
#
#
# @@@@@@@@@@@@@@
# 127.40484380722046
#
#
# @@@@@@@@@@@@@@
# 130.44386458396912
#
#
# @@@@@@@@@@@@@@
# 134.7272651195526
#
#
# @@@@@@@@@@@@@@
# 128.03602170944214
#
#
# @@@@@@@@@@@@@@
# 128.36407017707825
#
#
# @@@@@@@@@@@@@@
# 127.13205480575562
#
#
# @@@@@@@@@@@@@@
# 129.57881116867065
#
#
# @@@@@@@@@@@@@@
# 130.88833332061768
#
#
# @@@@@@@@@@@@@@
# 129.93193244934082
#
#
# @@@@@@@@@@@@@@
# 129.2223756313324
#
#
# @@@@@@@@@@@@@@
# 128.576899766922
#
#
# @@@@@@@@@@@@@@
# 131.5134289264679
#
#
# @@@@@@@@@@@@@@
# 131.44656538963318
#
#
# @@@@@@@@@@@@@@
# 134.5286204814911
#
#
# @@@@@@@@@@@@@@
# 136.71217370033264
#
#
# @@@@@@@@@@@@@@
# 125.46592402458191
#
#
# @@@@@@@@@@@@@@

# %%
def fsl_reg2mm(subjectNamesList):
    fslSubject = p(f'{fsl2mmThreaded}/{subjectNamesList}')
    try:
        os.mkdir(fslSubject)
    except OSError:
        pass
    
    movingImageName = os.listdir(f'{pipeline0}/{subjectNamesList}')  
    movingImage = p(f'{pipeline0}/{subjectNamesList}/{movingImageName[0]}')
    
    os.chdir(fslSubject)
    
    start = time.time()
    
    rc1 = run(f'flirt -ref {template2mm} -in {movingImage} -omat affine.mat', shell=True)
    
    matrixFile = f'{fslSubject}/affine.mat'
    
    rc2 = run(f'fnirt --in={movingImage} --aff={matrixFile} --cout=nonLinear --config=T1_2_MNI152_2mm', shell=True)
      
    nonLinear = f'{fslSubject}/nonLinear.nii.gz'

    rc3 = run(f'applywarp --ref={template} --in={movingImage} --warp={nonLinear} --out=warpedStructural', shell=True)

    
    end = time.time()
    processingTime = end - start
    
    try:
        os.remove('affine.mat')
    except OSError:
        pass
    try:
        os.remove('nonLinear.nii.gz')
    except OSError:
        pass
    
    return processingTime

# %%
subjectNumber = ['Subject Number']
processingTime = ['FSL2mm Processing Time (seconds)']

#fsl registration directory = ants
fsl2mmThreaded = p(f'{pipeline1}/fsl2mmThreaded')
try:
    os.mkdir(fsl2mmThreaded)
except OSError:
    pass

#loop for full FSL Threaded reg
startThreaded = time.time() 

if __name__ == '__main__':
    pool = Pool(4)
    a = pool.map(fsl_reg2mm, subject)
    pool.close()
    pool.join()
    
endThreaded = time.time()


subjectNumber.extend(subject)
processingTime.extend(a)

fu = np.column_stack((subjectNumber, processingTime))
fubar = fu.transpose()
print('Overall 2mm Threaded Time')
print(endThreaded - startThreaded)
np.savetxt(p(f'{outputResults}/FSL2mmThreaded_time.csv'), fubar, fmt='%s', delimiter = ',')
# Out:
# Overall 2mm Threaded Time
# 6776.451681137085
